# %%
# !pip install py4j pyspark
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting py4j
#   Downloading py4j-0.10.9.7-py2.py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.5/200.5 KB 6.3 MB/s eta 0:00:00
# Collecting pyspark
#   Downloading pyspark-3.3.1.tar.gz (281.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 281.4/281.4 MB 4.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting py4j
#   Downloading py4j-0.10.9.5-py2.py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.7/199.7 KB 14.2 MB/s eta 0:00:00
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.3.1-py2.py3-none-any.whl size=281845512 sha256=ee30f462288d0406d07fbb7cb7ca0a2381e4d784a873bafb2d70d6cda85a5152
#   Stored in directory: /root/.cache/pip/wheels/43/dc/11/ec201cd671da62fa9c5cc77078235e40722170ceba231d7598
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.9.5 pyspark-3.3.1

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('Cluster').getOrCreate()
from pyspark.ml.clustering import KMeans
dataset = spark.read.format('libsvm').load('/content/drive/MyDrive/Colab Notebooks/data/sample_kmeans_data.txt')
dataset.show()
# Out:
# +-----+--------------------+
# |label|            features|
# +-----+--------------------+
# |  0.0|           (3,[],[])|
# |  1.0|(3,[0,1,2],[0.1,0...|
# |  2.0|(3,[0,1,2],[0.2,0...|
# |  3.0|(3,[0,1,2],[9.0,9...|
# |  4.0|(3,[0,1,2],[9.1,9...|
# |  5.0|(3,[0,1,2],[9.2,9...|
# +-----+--------------------+

# %%
final_data = dataset.select('features')

# %%
final_data.show()
# Out:
# +--------------------+
# |            features|
# +--------------------+
# |           (3,[],[])|
# |(3,[0,1,2],[0.1,0...|
# |(3,[0,1,2],[0.2,0...|
# |(3,[0,1,2],[9.0,9...|
# |(3,[0,1,2],[9.1,9...|
# |(3,[0,1,2],[9.2,9...|
# +--------------------+

# %%
## Lets Create an UnSupervised Learning Algorithm using K Means Clustering
kmeans = KMeans().setK(2).setSeed(1)
model = kmeans.fit(final_data)

# %%
centers = model.clusterCenters()

# %%
centers
# Out:
# [array([9.1, 9.1, 9.1]), array([0.1, 0.1, 0.1])]

# %%
final_data.show()
# Out:
# +--------------------+
# |            features|
# +--------------------+
# |           (3,[],[])|
# |(3,[0,1,2],[0.1,0...|
# |(3,[0,1,2],[0.2,0...|
# |(3,[0,1,2],[9.0,9...|
# |(3,[0,1,2],[9.1,9...|
# |(3,[0,1,2],[9.2,9...|
# +--------------------+

# %%
results = model.transform(final_data)
results.show()
# Out:
# +--------------------+----------+
# |            features|prediction|
# +--------------------+----------+
# |           (3,[],[])|         1|
# |(3,[0,1,2],[0.1,0...|         1|
# |(3,[0,1,2],[0.2,0...|         1|
# |(3,[0,1,2],[9.0,9...|         0|
# |(3,[0,1,2],[9.1,9...|         0|
# |(3,[0,1,2],[9.2,9...|         0|
# +--------------------+----------+
